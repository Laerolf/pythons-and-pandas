# %%
import pandas as pandas

data = pandas.read_csv('../../data/NYC airbnb/AB_NYC_2019.csv');

# %%
counts = data.host_id.value_counts().to_frame()
counts.columns = ['registration_count']
counts
# Out:
#            registration_count
# 219517861                 327
# 107434423                 232
# 30283594                  121
# 137358866                 103
# 12243051                   96
# 16098958                   96
# 61391963                   91
# 22541573                   87
# 200380610                  65
# 7503643                    52
# 1475015                    52
# 120762452                  50
# 2856748                    49
# 205031545                  49
# 190921808                  47
# 26377263                   43
# 2119276                    39
# 19303369                   37
# 25237492                   34
# 119669058                  34
# 76104209                   33
# 113805886                  33
# 213781715                  33
# 238321374                  32
# 51501835                   31
# 50760546                   31
# 224414117                  30
# 13347167                   29
# 39528519                   28
# 417504                     28
# ...
