# %%
import pandas
import numpy

# LOAD TRAIN DATA

train_data = pandas.read_csv("../../data/titanic/train.csv")

train_data.head(25)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 13      5            347082  31.2750   NaN        S
# 14      0            350406   7.8542   NaN        S
# 15      0            248706  16.0000   NaN        S
# 16      1            382652  29.1250   NaN        Q
# 17      0            244373  13.0000   NaN        S
# 18      0            345763  18.0000   NaN        S
# 19      0              2649   7.2250   NaN        C
# 20      0            239865  26.0000   NaN        S
# 21      0            248698  13.0000   D56        S
# 22      0            330923   8.0292   NaN        Q
# 23      0            113788  35.5000    A6        S
# 24      1            349909  21.0750   NaN        S

# %%
# CLEAN TRAIN DATA I

print("PRE-CLEAN: TOTAL AMOUNT OF RECORDS: {} \n".format(len(train_data)))

for column in train_data.columns:
    
    print("{}: {} empty records".format(column, len(train_data.loc[pandas.isnull(train_data[column])])))
    
# DELETING ROWS WITHOUT AGE

train_data = train_data[pandas.notnull(train_data.Age)]

# DELETING CABIN COLUMN

del train_data['Cabin']

print("\nPOST-CLEAN: TOTAL AMOUNT OF RECORDS: {} \n".format(len(train_data)))
# Out:
# PRE-CLEAN: TOTAL AMOUNT OF RECORDS: 891
#
# PassengerId: 0 empty records
# Survived: 0 empty records
# Pclass: 0 empty records
# Name: 0 empty records
# Sex: 0 empty records
# Age: 177 empty records
# SibSp: 0 empty records
# Parch: 0 empty records
# Ticket: 0 empty records
# Fare: 0 empty records
# Cabin: 687 empty records
# Embarked: 2 empty records
#
# POST-CLEAN: TOTAL AMOUNT OF RECORDS: 714

# %%
## SOMETHING ABOUT EMBARKED

train_data.loc[pandas.isnull(train_data.Embarked)]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Embarked
# 61   female  38.0      0      0  113572  80.0      NaN
# 829  female  62.0      0      0  113572  80.0      NaN

# %%
# CLEAN TRAIN DATA II

## ADD AGE CLASSIFICATION

train_data.insert(6, 'AgeClass', '')

ageClassifications = [
    {
        'name': 'Child',
        'min': 0,
        'max': 14
    },
    {
        'name': 'Young adult',
        'min': 15,
        'max': 24
    },
    {
        'name': 'Adult',
        'min': 25,
        'max': 50
    },
    {
        'name': 'Senior',
        'min': 51,
        'max': 80
    }
]

for index, row in train_data.iterrows():
    
    rowAge = row['Age']
    ageClass = 'Senior'
    
    for ageClassification in ageClassifications:
        
        if ageClassification['min'] <= rowAge and rowAge <= ageClassification['max']:
            
            ageClass = ageClassification['name']
            
    train_data.at[index, 'AgeClass'] = ageClass

## SORT DATA ON TICKET NUMBER AND PASSENGER ID

train_data = train_data.sort_values(by=['Ticket', 'PassengerId'])

train_data[train_data.duplicated(subset=['Ticket'], keep=False)]
# Out:
#      PassengerId  Survived  Pclass  \
# 257          258         1       1
# 504          505         1       1
# 759          760         1       1
# 262          263         0       1
# 558          559         1       1
# 585          586         1       1
# 329          330         1       1
# 523          524         1       1
# 61            62         1       1
# 829          830         1       1
# 390          391         1       1
# 435          436         1       1
# 763          764         1       1
# 802          803         1       1
# 151          152         1       1
# 336          337         0       1
# 297          298         0       1
# 305          306         1       1
# 498          499         0       1
# 708          709         1       1
# 35            36         0       1
# 383          384         1       1
# 3              4         1       1
# 137          138         0       1
# 724          725         1       1
# 809          810         1       1
# 41            42         0       2
# 117          118         0       2
# 248          249         1       1
# 871          872         1       1
# ..           ...       ...     ...
# 716          717         1       1
# 307          308         1       1
# 505          506         0       1
# 269          270         1       1
# 325          326         1       1
# 373          374         0       1
# 537          538         1       1
# 544          545         0       1
# 10            11         1       3
# 394          395         1       3
# 817          818         0       2
# 827          828         1       2
# 772          773         0       2
# 841          842         0       2
# 72            73         0       2
# 120          121         0       2
# 385          386         0       2
# 655          656         0       2
# 665          666         0       2
# 43            44         1       2
# 608          609         1       2
# 685          686         0       2
# 142          143         1       3
# 403          404         0       3
# 86            87         0       3
# 147          148         0       3
# 436          437         0       3
# 736          737         0       3
# 540          541         1       1
# 745          746         0       1
#
#                                                   Name     Sex    Age  \
# 257                               Cherry, Miss. Gladys  female  30.00
# 504                              Maioni, Miss. Roberta  female  16.00
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.00
# 262                                  Taussig, Mr. Emil    male  52.00
# 558             Taussig, Mrs. Emil (Tillie Mandelbaum)  female  39.00
# 585                                Taussig, Miss. Ruth  female  18.00
# 329                       Hippach, Miss. Jean Gertrude  female  16.00
# 523    Hippach, Mrs. Louis Albert (Ida Sophia Fischer)  female  44.00
# 61                                 Icard, Miss. Amelie  female  38.00
# 829          Stone, Mrs. George Nelson (Martha Evelyn)  female  62.00
# 390                         Carter, Mr. William Ernest    male  36.00
# 435                          Carter, Miss. Lucile Polk  female  14.00
# 763          Carter, Mrs. William Ernest (Lucile Polk)  female  36.00
# 802                Carter, Master. William Thornton II    male  11.00
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female  22.00
# 336                          Pears, Mr. Thomas Clinton    male  29.00
# 297                       Allison, Miss. Helen Loraine  female   2.00
# 305                     Allison, Master. Hudson Trevor    male   0.92
# 498    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# 708                               Cleaver, Miss. Alice  female  22.00
# 35                      Holverson, Mr. Alexander Oskar    male  42.00
# 383  Holverson, Mrs. Alexander Oskar (Mary Aline To...  female  35.00
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00
# 137                        Futrelle, Mr. Jacques Heath    male  37.00
# 724                      Chambers, Mr. Norman Campbell    male  27.00
# 809     Chambers, Mrs. Norman Campbell (Bertha Griggs)  female  33.00
# 41   Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.00
# 117                    Turpin, Mr. William John Robert    male  29.00
# 248                      Beckwith, Mr. Richard Leonard    male  37.00
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.00
# ..                                                 ...     ...    ...
# 716                      Endres, Miss. Caroline Louise  female  38.00
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.00
# 505         Penasco y Castellana, Mr. Victor de Satode    male  18.00
# 269                             Bissette, Miss. Amelia  female  35.00
# 325                           Young, Miss. Marie Grice  female  36.00
# 373                                Ringhini, Mr. Sante    male  22.00
# 537                                LeRoy, Miss. Bertha  female  30.00
# 544                         Douglas, Mr. Walter Donald    male  50.00
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.00
# 394  Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female  24.00
# 817                                 Mallet, Mr. Albert    male  31.00
# 827                              Mallet, Master. Andre    male   1.00
# 772                                  Mack, Mrs. (Mary)  female  57.00
# 841                           Mudd, Mr. Thomas Charles    male  16.00
# 72                                Hood, Mr. Ambrose Jr    male  21.00
# 120                        Hickman, Mr. Stanley George    male  21.00
# 385                          Davies, Mr. Charles Henry    male  18.00
# 655                          Hickman, Mr. Leonard Mark    male  24.00
# 665                                 Hickman, Mr. Lewis    male  32.00
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.00
# 608  Laroche, Mrs. Joseph (Juliette Marie Louise La...  female  22.00
# 685             Laroche, Mr. Joseph Philippe Lemercier    male  25.00
# 142  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...  female  24.00
# 403                     Hakkarainen, Mr. Pekka Pietari    male  28.00
# 86                              Ford, Mr. William Neal    male  16.00
# 147                   Ford, Miss. Robina Maggie "Ruby"  female   9.00
# 436               Ford, Miss. Doolina Margaret "Daisy"  female  21.00
# 736            Ford, Mrs. Edward (Margaret Ann Watson)  female  48.00
# 540                            Crosby, Miss. Harriet R  female  36.00
# 745                       Crosby, Capt. Edward Gifford    male  70.00
#
#         AgeClass  SibSp  Parch            Ticket      Fare Embarked
# 257        Adult      0      0            110152   86.5000        S
# 504  Young adult      0      0            110152   86.5000        S
# 759        Adult      0      0            110152   86.5000        S
# 262       Senior      1      1            110413   79.6500        S
# 558        Adult      1      1            110413   79.6500        S
# 585  Young adult      0      2            110413   79.6500        S
# 329  Young adult      0      1            111361   57.9792        C
# 523        Adult      0      1            111361   57.9792        C
# 61         Adult      0      0            113572   80.0000      NaN
# 829       Senior      0      0            113572   80.0000      NaN
# 390        Adult      1      2            113760  120.0000        S
# 435        Child      1      2            113760  120.0000        S
# 763        Adult      1      2            113760  120.0000        S
# 802        Child      1      2            113760  120.0000        S
# 151  Young adult      1      0            113776   66.6000        S
# 336        Adult      1      0            113776   66.6000        S
# 297        Child      1      2            113781  151.5500        S
# 305        Child      1      2            113781  151.5500        S
# 498        Adult      1      2            113781  151.5500        S
# 708  Young adult      0      0            113781  151.5500        S
# 35         Adult      1      0            113789   52.0000        S
# 383        Adult      1      0            113789   52.0000        S
# 3          Adult      1      0            113803   53.1000        S
# 137        Adult      1      0            113803   53.1000        S
# 724        Adult      1      0            113806   53.1000        S
# 809        Adult      1      0            113806   53.1000        S
# 41         Adult      1      0             11668   21.0000        S
# 117        Adult      1      0             11668   21.0000        S
# 248        Adult      1      1             11751   52.5542        S
# 871        Adult      1      1             11751   52.5542        S
# ..           ...    ...    ...               ...       ...      ...
# 716        Adult      0      0          PC 17757  227.5250        C
# 307  Young adult      1      0          PC 17758  108.9000        C
# 505  Young adult      1      0          PC 17758  108.9000        C
# 269        Adult      0      0          PC 17760  135.6333        S
# 325        Adult      0      0          PC 17760  135.6333        C
# 373  Young adult      0      0          PC 17760  135.6333        C
# 537        Adult      0      0          PC 17761  106.4250        C
# 544        Adult      1      0          PC 17761  106.4250        C
# 10         Child      1      1           PP 9549   16.7000        S
# 394  Young adult      0      2           PP 9549   16.7000        S
# 817        Adult      1      1   S.C./PARIS 2079   37.0042        C
# 827        Child      0      2   S.C./PARIS 2079   37.0042        C
# 772       Senior      0      0       S.O./P.P. 3   10.5000        S
# 841  Young adult      0      0       S.O./P.P. 3   10.5000        S
# 72   Young adult      0      0      S.O.C. 14879   73.5000        S
# 120  Young adult      2      0      S.O.C. 14879   73.5000        S
# 385  Young adult      0      0      S.O.C. 14879   73.5000        S
# 655  Young adult      2      0      S.O.C. 14879   73.5000        S
# 665        Adult      2      0      S.O.C. 14879   73.5000        S
# 43         Child      1      2     SC/Paris 2123   41.5792        C
# 608  Young adult      1      2     SC/Paris 2123   41.5792        C
# 685        Adult      1      2     SC/Paris 2123   41.5792        C
# 142  Young adult      1      0  STON/O2. 3101279   15.8500        S
# 403        Adult      1      0  STON/O2. 3101279   15.8500        S
# 86   Young adult      1      3        W./C. 6608   34.3750        S
# 147        Child      2      2        W./C. 6608   34.3750        S
# 436  Young adult      2      2        W./C. 6608   34.3750        S
# 736        Adult      1      3        W./C. 6608   34.3750        S
# 540        Adult      0      2         WE/P 5735   71.0000        S
# 745       Senior      1      1         WE/P 5735   71.0000        S
#
# [283 rows x 12 columns]

# %%
train_data.groupby(["AgeClass"]).mean().sort_values(by='Survived')
# Out:
#              PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# AgeClass
# Senior        442.378788  0.333333  1.590909  57.530303  0.257576  0.287879
# Young adult   432.623116  0.366834  2.462312  20.190955  0.386935  0.321608
# Adult         462.529570  0.403226  2.150538  34.814516  0.352151  0.327957
# Child         427.766234  0.584416  2.623377   5.703506  1.831169  1.337662
#
#                   Fare
# AgeClass
# Senior       42.624433
# Young adult  31.117734
# Adult        35.773521
# Child        31.928464
